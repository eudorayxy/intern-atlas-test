# %% [markdown]
# # The Experiment
# This experiment uses custom modules in the *backend* folder, which have been specifically developed for this third-year lab. This notebook works directly with the **13 TeV 2025 ATLAS Open Data**.
#
# Please run the cell below to install the required packages. You will need to do this **each time you start the server**.

# %%
# !pip install atlasopenmagic
# !pip install pyarrow==20.0.0 awkward==2.8.5
from atlasopenmagic import install_from_environment
install_from_environment(environment_file="environment.yml")
# Out:
# Requirement already satisfied: atlasopenmagic in /opt/conda/lib/python3.12/site-packages (1.2.0)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.12/site-packages (from atlasopenmagic) (6.0.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.12/site-packages (from atlasopenmagic) (2.32.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests->atlasopenmagic) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests->atlasopenmagic) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests->atlasopenmagic) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests->atlasopenmagic) (2025.1.31)
# Requirement already satisfied: pyarrow==20.0.0 in /opt/conda/lib/python3.12/site-packages (20.0.0)
# Requirement already satisfied: awkward==2.8.5 in /opt/conda/lib/python3.12/site-packages (2.8.5)
# Requirement already satisfied: awkward-cpp==47 in /opt/conda/lib/python3.12/site-packages (from awkward==2.8.5) (47)
# Requirement already satisfied: fsspec>=2022.11.0 in /opt/conda/lib/python3.12/site-packages (from awkward==2.8.5) (2025.3.2)
# Requirement already satisfied: numpy>=1.18.0 in /opt/conda/lib/python3.12/site-packages (from awkward==2.8.5) (1.26.4)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from awkward==2.8.5) (24.2)

# %% [markdown]
# Next, run the cell below to import the required modules and functions for the experiment. Repeat this step **every time you restart the kernel**.

# %%
import sys
import os
import re
import awkward as ak 
import vector
import time
import datetime
from zoneinfo import ZoneInfo
import uproot
import glob
import numpy as np
import hist
from hist import Hist
import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator # for minor ticks
from collections import defaultdict

from backend import analysis_uproot, Dids_dict, validSkims, plot_stacked_hist, plot_histograms, analysis_read_parquet, plot_errorbars
# Out:
# Active release set to: 2025e-13tev-beta. Metadata cache cleared.

# %% [markdown]
# ## Accessing Data Samples
# Data samples stored in the *backend* folder can be accessed using `skim` **and** a *string code*, passed to the `analysis_uproot` function. The key `skim` and string codes are listed below:
#
# #### `Skim` (Final-State Filters)
# * `'2to4lep'` - Events with two to four leptons, each with at least 7 GeV of transverse momentum $p_T$
# * `'GamGam'` - Events with at least two photons, each with at least 25 GeV of $p_T$
#
# #### String Codes
# * `'Data'` - Real data
# * `'Zee'` - Simulated $Z \rightarrow e^+e^-$ events
# * `'Zmumu'` - Simulated $Z \rightarrow \mu^+\mu^-$ events
# * `'Hyy'` - Simulated $H \rightarrow \gamma \gamma$ events
#
# > **Note**: The string code for real data is always `'Data'`, regardless of the `skim` used.
#
# To combine multiple datasets, combine the string codes using `'+'`. For example, if you would like to combine the $Z \rightarrow \mu^+\mu^-$ and $Z \rightarrow e^+e^-$ datasets, use the string code `'Zee+Zmumu'`.
#
# All available `skim` can be viewed with `validSkims`, and all string codes with `Dids_dict.keys()`.

# %%
validSkims
# Out:
# ['2to4lep',
#  '2muons',
#  'GamGam',
#  'exactly4lep',
#  '1LMET30',
#  '3J1LMET30',
#  '2J2LMET30',
#  '2bjets',
#  '3lep',
#  'exactly3lep',
#  '4lep']

# %%
Dids_dict.keys()
# Out:
# dict_keys(['Zee', 'Zmumu', 'Ztautau', 'VBF_Zee', 'VBF_Zmumu', 'VBF_Ztautau', 'Wenu', 'Wmunu', 'Wtaunu', 'VBF_Wenu', 'VBF_Wmunu', 'VBF_Wtaunu', 'ttbar', 'VV4l', 'm10_40_Zee', 'm10_40_Zmumu', 'ggF_Hyy', 'VBF_Hyy', 'WpH_Hyy', 'WmH_Hyy', 'ZH_Hyy', 'ggZH_Hyy', 'ttH_Hyy', 'ggH_H4l', 'VBF_H4l', 'ttH_H4l', 'ggZH_H4l', 'ZH_H4l', 'WpH_H4l', 'WmH_H4l', 'VBF_Zll', 'm10_40_Zll', 'Wlepnu', 'VBF_Wlepnu', 'Hyy', 'H4l'])

# %% [markdown]
# To use `analysis_uproot`, the following arguments must be provided:
# - `string_code_dict` (*dict*) : Maps dataset labels to string codes
#   - **Keys**: Labels used in the output dictionary of Awkward Arrays
#         - Must include 'Data' in the key for real data. When detected, `analysis_uproot` will skip weight calculation for that sample to reduce memory usage.
#   - **Values**: The corresponding string codes
#   - **Example**:
#     ```
#     string_code_dict = {
#         'Data' : 'Data',
#         'Signal Zee' : 'Zee',
#         'Background Wenu+Wmunu' : 'Wenu+Wmunu'
#     }
#     ```
# - `skim` (*str*) e.g. `'2to4lep'`
# - `luminosity` (*float*) : Integrated luminosity in fb⁻¹, e.g. `36.6`.
# - `fraction` (*float*) : Fraction of each dataset to read, e.g. `0.1` for 10%
# - `read_variables` (*list of str*) : Names of ROOT branches to read
# - `save_variables`(*list of str*) : Variables to keep in memory or write to disk
#
# Optional argument:
# - `cut_function` (*callable*): Function that receives an argument and returns it. Can be used to:
#     - Apply selection cuts
#     - Compute derived variables using the data in `read_variables`, e.g. invariant mass
# - `write_parquet` (*bool*) : Set to `True` to write output to Parquet files
# - `output_directory` (*str or None*) :
#    - Directory where files will be saved
#    - If `None`, a unique folder in `output/` will be created using the current date and time
# - `write_txt` (*bool*) : Set to `True` to write a summary log of the run
# - `txt_filename` (*str or None*) : Filename for the summary log. If not provided, a unique file will be created in the `txt/` folder.
# - `return_output` (*bool*)
#   - `True` (default) : Returns the output dictionary of Awkward Arrays
#   - `False` : Nothing is returned (saves memory when only writing to disk)

# %%
string_code_dict = {
    'Data' : 'Data',
    'Signal Zee' : 'Zee',
    'Signal Zmumu' : 'Zmumu',
    'Background Wenu+Wmunu' : 'Wenu+Wmunu',
    'Background VV4l+H4l' : 'VV4l+H4l'
}
skim = '2to4lep'
luminosity = 36.6
fraction = 0.01
read_variables = ['lep_n', 'lep_pt',
                 'lep_eta', 'lep_phi', 'lep_e']
save_variables = read_variables

def pt_30_cut(data):
    data = data[data['lep_n'] == 2]
    
    pt_cut = (data['lep_pt'][:, 0] > 30) & (data['lep_pt'][:, 1] > 30)
    data = data[pt_cut]
    # Define four momentum
    four_momentum = vector.zip({
        'pt': data['lep_pt'],
        'eta' : data['lep_eta'],
        'phi' : data['lep_phi'],
        'E' : data['lep_e']
    })
    # Add the 4-momentum of the two leptons in each event and get the 
    # invariant mass using .M
    data['mass'] = (four_momentum[:, 0] + four_momentum[:, 1]).M
    return data


pt30_data = analysis_uproot(skim, string_code_dict, luminosity, fraction, 
                read_variables, save_variables, cut_function=pt_30_cut)
pt30_data
# Out:
# Fetching and caching all metadata for release: 2025e-13tev-beta...
# Successfully cached 374 datasets.
# File ODEO_FEB2025_v0_2to4lep_data15_periodD.2to4lep.root already exists in backend/datasets/2to4lep/Data. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_data15_periodE.2to4lep.root already exists in backend/datasets/2to4lep/Data. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_data15_periodF.2to4lep.root already exists in backend/datasets/2to4lep/Data. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_data15_periodG.2to4lep.root already exists in backend/datasets/2to4lep/Data. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_data15_periodH.2to4lep.root already exists in backend/datasets/2to4lep/Data. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_data15_periodJ.2to4lep.root already exists in backend/datasets/2to4lep/Data. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_data16_periodA.2to4lep.root already exists in backend/datasets/2to4lep/Data. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_data16_periodB.2to4lep.root already exists in backend/datasets/2to4lep/Data. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_data16_periodC.2to4lep.root already exists in backend/datasets/2to4lep/Data. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_data16_periodD.2to4lep.root already exists in backend/datasets/2to4lep/Data. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_data16_periodE.2to4lep.root already exists in backend/datasets/2to4lep/Data. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_data16_periodF.2to4lep.root already exists in backend/datasets/2to4lep/Data. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_data16_periodG.2to4lep.root already exists in backend/datasets/2to4lep/Data. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_data16_periodI.2to4lep.root already exists in backend/datasets/2to4lep/Data. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_data16_periodK.2to4lep.root already exists in backend/datasets/2to4lep/Data. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_data16_periodL.2to4lep.root already exists in backend/datasets/2to4lep/Data. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_700320.Sh_2211_Zee_maxHTpTV2_BFilter.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_700321.Sh_2211_Zee_maxHTpTV2_CFilterBVeto.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_700322.Sh_2211_Zee_maxHTpTV2_CVetoBVeto.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_700323.Sh_2211_Zmumu_maxHTpTV2_BFilter.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_700324.Sh_2211_Zmumu_maxHTpTV2_CFilterBVeto.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_700325.Sh_2211_Zmumu_maxHTpTV2_CVetoBVeto.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_700338.Sh_2211_Wenu_maxHTpTV2_BFilter.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_700339.Sh_2211_Wenu_maxHTpTV2_CFilterBVeto.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_700340.Sh_2211_Wenu_maxHTpTV2_CVetoBVeto.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_700341.Sh_2211_Wmunu_maxHTpTV2_BFilter.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_700342.Sh_2211_Wmunu_maxHTpTV2_CFilterBVeto.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_700343.Sh_2211_Wmunu_maxHTpTV2_CVetoBVeto.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_700600.Sh_2212_llll.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_700587.Sh_2212_lllljj.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_700591.Sh_2212_lllljj_Int.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_345060.PowhegPythia8EvtGen_NNLOPS_nnlo_30_ggH125_ZZ4l.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_346228.PowhegPy8EG_NNPDF30_AZNLOCTEQ6L1_VBFH125_ZZ4lep_notau.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_346646.PowhegPythia8EvtGen_NNPDF30_AZNLO_WpH125J_Wincl_MINLO_shw.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_346647.PowhegPythia8EvtGen_NNPDF30_AZNLO_WmH125J_Wincl_MINLO_shw.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_346645.PowhegPythia8EvtGen_NNPDF30_AZNLO_ZH125J_Zincl_MINLO_shw.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_345066.PowhegPythia8EvtGen_NNPDF3_AZNLO_ggZH125_ZZ4lepZinc.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_346340.PowhegPy8EG_A14NNPDF23_NNPDF30ME_ttH125_ZZ4l_allhad.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_346341.PowhegPy8EG_A14NNPDF23_NNPDF30ME_ttH125_ZZ4l_semilep.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_346342.PowhegPy8EG_A14NNPDF23_NNPDF30ME_ttH125_ZZ4l_dilep.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# Processing "Data" samples
# 	backend/datasets/2to4lep/Data/ODEO_FEB2025_v0_2to4lep_data15_periodD.2to4lep.root :
# 		 nIn: 8802,	 nOut: 	684	 in 0.4 s
# 	backend/datasets/2to4lep/Data/ODEO_FEB2025_v0_2to4lep_data15_periodE.2to4lep.root :
# 		 nIn: 65261,	 nOut: 	5731	 in 0.2 s
# 	backend/datasets/2to4lep/Data/ODEO_FEB2025_v0_2to4lep_data15_periodF.2to4lep.root :
# 		 nIn: 41832,	 nOut: 	3546	 in 0.2 s
# 	backend/datasets/2to4lep/Data/ODEO_FEB2025_v0_2to4lep_data15_periodG.2to4lep.root :
# 		 nIn: 93682,	 nOut: 	9041	 in 0.3 s
# 	backend/datasets/2to4lep/Data/ODEO_FEB2025_v0_2to4lep_data15_periodH.2to4lep.root :
# 		 nIn: 28656,	 nOut: 	3119	 in 0.1 s
# 	backend/datasets/2to4lep/Data/ODEO_FEB2025_v0_2to4lep_data15_periodJ.2to4lep.root :
# 		 nIn: 161720,	 nOut: 	17926	 in 0.5 s
# 	backend/datasets/2to4lep/Data/ODEO_FEB2025_v0_2to4lep_data16_periodA.2to4lep.root :
# 		 nIn: 73689,	 nOut: 	7155	 in 0.3 s
# 	backend/datasets/2to4lep/Data/ODEO_FEB2025_v0_2to4lep_data16_periodB.2to4lep.root :
# 		 nIn: 160015,	 nOut: 	21691	 in 0.5 s
# 	backend/datasets/2to4lep/Data/ODEO_FEB2025_v0_2to4lep_data16_periodC.2to4lep.root :
# 		 nIn: 207419,	 nOut: 	26153	 in 0.6 s
# 	backend/datasets/2to4lep/Data/ODEO_FEB2025_v0_2to4lep_data16_periodD.2to4lep.root :
# 		 nIn: 364708,	 nOut: 	58178	 in 0.8 s
# 	backend/datasets/2to4lep/Data/ODEO_FEB2025_v0_2to4lep_data16_periodE.2to4lep.root :
# 		 nIn: 113729,	 nOut: 	19418	 in 0.3 s
# 	backend/datasets/2to4lep/Data/ODEO_FEB2025_v0_2to4lep_data16_periodF.2to4lep.root :
# 		 nIn: 232306,	 nOut: 	41927	 in 0.6 s
# 	backend/datasets/2to4lep/Data/ODEO_FEB2025_v0_2to4lep_data16_periodG.2to4lep.root :
# 		 nIn: 263551,	 nOut: 	44201	 in 0.6 s
# 	backend/datasets/2to4lep/Data/ODEO_FEB2025_v0_2to4lep_data16_periodI.2to4lep.root :
# 		 nIn: 411269,	 nOut: 	70180	 in 0.9 s
# 	backend/datasets/2to4lep/Data/ODEO_FEB2025_v0_2to4lep_data16_periodK.2to4lep.root :
# 		 nIn: 164911,	 nOut: 	28940	 in 0.4 s
# 	backend/datasets/2to4lep/Data/ODEO_FEB2025_v0_2to4lep_data16_periodL.2to4lep.root :
# 		 nIn: 447961,	 nOut: 	76193	 in 1.0 s
# Processing "Signal Zee" samples
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_700320.Sh_2211_Zee_maxHTpTV2_BFilter.2to4lep.root :
# 		 nIn: 24697,	 nOut: 	8826.069	 in 0.2 s
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_700321.Sh_2211_Zee_maxHTpTV2_CFilterBVeto.2to4lep.root :
# 		 nIn: 109942,	 nOut: 	32853.885	 in 0.5 s
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_700322.Sh_2211_Zee_maxHTpTV2_CVetoBVeto.2to4lep.root :
# 		 nIn: 399444,	 nOut: 	177908.397	 in 1.3 s
# Processing "Signal Zmumu" samples
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_700323.Sh_2211_Zmumu_maxHTpTV2_BFilter.2to4lep.root :
# 		 nIn: 24378,	 nOut: 	8540.403	 in 0.2 s
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_700324.Sh_2211_Zmumu_maxHTpTV2_CFilterBVeto.2to4lep.root :
# 		 nIn: 115270,	 nOut: 	34229.809	 in 0.5 s
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_700325.Sh_2211_Zmumu_maxHTpTV2_CVetoBVeto.2to4lep.root :
# 		 nIn: 430696,	 nOut: 	192652.37	 in 1.5 s
# Processing "Background Wenu+Wmunu" samples
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_700338.Sh_2211_Wenu_maxHTpTV2_BFilter.2to4lep.root :
# 		 nIn: 6220,	 nOut: 	64.403	 in 0.1 s
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_700339.Sh_2211_Wenu_maxHTpTV2_CFilterBVeto.2to4lep.root :
# 		 nIn: 28590,	 nOut: 	306.142	 in 0.2 s
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_700340.Sh_2211_Wenu_maxHTpTV2_CVetoBVeto.2to4lep.root :
# 		 nIn: 19953,	 nOut: 	519.738	 in 0.1 s
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_700341.Sh_2211_Wmunu_maxHTpTV2_BFilter.2to4lep.root :
# 		 nIn: 6602,	 nOut: 	73.126	 in 0.1 s
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_700342.Sh_2211_Wmunu_maxHTpTV2_CFilterBVeto.2to4lep.root :
# 		 nIn: 26473,	 nOut: 	269.129	 in 0.2 s
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_700343.Sh_2211_Wmunu_maxHTpTV2_CVetoBVeto.2to4lep.root :
# 		 nIn: 17640,	 nOut: 	486.929	 in 0.1 s
# Processing "Background VV4l+H4l" samples
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_700600.Sh_2212_llll.2to4lep.root :
# 		 nIn: 1045,	 nOut: 	32.818	 in 0.1 s
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_700587.Sh_2212_lllljj.2to4lep.root :
# 		 nIn: 461,	 nOut: 	0.565	 in 0.1 s
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_700591.Sh_2212_lllljj_Int.2to4lep.root :
# 		 nIn: 59,	 nOut: 	0.974	 in 0.0 s
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_345060.PowhegPythia8EvtGen_NNLOPS_nnlo_30_ggH125_ZZ4l.2to4lep.root :
# 		 nIn: 13788,	 nOut: 	0.106	 in 0.2 s
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_346228.PowhegPy8EG_NNPDF30_AZNLOCTEQ6L1_VBFH125_ZZ4lep_notau.2to4lep.root :
# 		 nIn: 2604,	 nOut: 	0.01	 in 0.1 s
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_346646.PowhegPythia8EvtGen_NNPDF30_AZNLO_WpH125J_Wincl_MINLO_shw.2to4lep.root :
# 		 nIn: 490,	 nOut: 	0.008	 in 0.1 s
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_346647.PowhegPythia8EvtGen_NNPDF30_AZNLO_WmH125J_Wincl_MINLO_shw.2to4lep.root :
# 		 nIn: 259,	 nOut: 	0.004	 in 0.1 s
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_346645.PowhegPythia8EvtGen_NNPDF30_AZNLO_ZH125J_Zincl_MINLO_shw.2to4lep.root :
# 		 nIn: 867,	 nOut: 	0.006	 in 0.1 s
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_345066.PowhegPythia8EvtGen_NNPDF3_AZNLO_ggZH125_ZZ4lepZinc.2to4lep.root :
# 		 nIn: 278,	 nOut: 	0.001	 in 0.1 s
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_346340.PowhegPy8EG_A14NNPDF23_NNPDF30ME_ttH125_ZZ4l_allhad.2to4lep.root :
# 		 nIn: 262,	 nOut: 	0.001	 in 0.1 s
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_346341.PowhegPy8EG_A14NNPDF23_NNPDF30ME_ttH125_ZZ4l_semilep.2to4lep.root :
# 		 nIn: 231,	 nOut: 	0.0	 in 0.1 s
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_346342.PowhegPy8EG_A14NNPDF23_NNPDF30ME_ttH125_ZZ4l_dilep.2to4lep.root :
# 		 nIn: 174,	 nOut: 	0.0	 in 0.1 s
#
#
# Elapsed time: 27.5s
# {'Data': <Array [{lep_n: 2, lep_pt: [...], ...}, ...] type='434083 * {lep_n: int32, ...'>,
#  'Signal Zee': <Array [{lep_n: 2, lep_pt: [...], ...}, ...] type='300100 * {lep_n: int32, ...'>,
#  'Signal Zmumu': <Array [{lep_n: 2, lep_pt: [...], ...}, ...] type='313943 * {lep_n: int32, ...'>,
#  'Background Wenu+Wmunu': <Array [{lep_n: 2, lep_pt: [...], ...}, ...] type='17515 * {lep_n: int32, l...'>,
#  'Background VV4l+H4l': <Array [{lep_n: 2, lep_pt: [...], ...}, ...] type='1654 * {lep_n: int32, le...'>}

# %% [markdown]
# You can simply set `write_parquet = True` if you would like to write data to disk. It is recommended to set `return_output = False` to reduce memory usage if you choose to save output to Parquet files.

# %%
def pt_20_cut(data):
    data = data[data['lep_n'] == 2]

    pt_cut = (data['lep_pt'][:, 0] > 20) & (data['lep_pt'][:, 1] > 20)
    data = data[pt_cut]
    
    # Define four momentum
    four_momentum = vector.zip({
        'pt': data['lep_pt'],
        'eta' : data['lep_eta'],
        'phi' : data['lep_phi'],
        'E' : data['lep_e']
    })
    # Add the 4-momentum of the two leptons in each event and get the 
    # invariant mass using .M
    data['mass'] = (four_momentum[:, 0] + four_momentum[:, 1]).M
    return data

output_dir = 'output/pt20_cut'
pt20_data = analysis_uproot(skim, string_code_dict, luminosity, fraction, 
                read_variables, save_variables, cut_function=pt_20_cut,
                write_txt=False, txt_filename=None,
                write_parquet=True, output_directory=output_dir,
                return_output=False)
# Out:
# File ODEO_FEB2025_v0_2to4lep_data15_periodD.2to4lep.root already exists in backend/datasets/2to4lep/Data. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_data15_periodE.2to4lep.root already exists in backend/datasets/2to4lep/Data. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_data15_periodF.2to4lep.root already exists in backend/datasets/2to4lep/Data. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_data15_periodG.2to4lep.root already exists in backend/datasets/2to4lep/Data. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_data15_periodH.2to4lep.root already exists in backend/datasets/2to4lep/Data. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_data15_periodJ.2to4lep.root already exists in backend/datasets/2to4lep/Data. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_data16_periodA.2to4lep.root already exists in backend/datasets/2to4lep/Data. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_data16_periodB.2to4lep.root already exists in backend/datasets/2to4lep/Data. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_data16_periodC.2to4lep.root already exists in backend/datasets/2to4lep/Data. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_data16_periodD.2to4lep.root already exists in backend/datasets/2to4lep/Data. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_data16_periodE.2to4lep.root already exists in backend/datasets/2to4lep/Data. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_data16_periodF.2to4lep.root already exists in backend/datasets/2to4lep/Data. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_data16_periodG.2to4lep.root already exists in backend/datasets/2to4lep/Data. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_data16_periodI.2to4lep.root already exists in backend/datasets/2to4lep/Data. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_data16_periodK.2to4lep.root already exists in backend/datasets/2to4lep/Data. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_data16_periodL.2to4lep.root already exists in backend/datasets/2to4lep/Data. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_700320.Sh_2211_Zee_maxHTpTV2_BFilter.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_700321.Sh_2211_Zee_maxHTpTV2_CFilterBVeto.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_700322.Sh_2211_Zee_maxHTpTV2_CVetoBVeto.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_700323.Sh_2211_Zmumu_maxHTpTV2_BFilter.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_700324.Sh_2211_Zmumu_maxHTpTV2_CFilterBVeto.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_700325.Sh_2211_Zmumu_maxHTpTV2_CVetoBVeto.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_700338.Sh_2211_Wenu_maxHTpTV2_BFilter.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_700339.Sh_2211_Wenu_maxHTpTV2_CFilterBVeto.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_700340.Sh_2211_Wenu_maxHTpTV2_CVetoBVeto.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_700341.Sh_2211_Wmunu_maxHTpTV2_BFilter.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_700342.Sh_2211_Wmunu_maxHTpTV2_CFilterBVeto.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_700343.Sh_2211_Wmunu_maxHTpTV2_CVetoBVeto.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_700600.Sh_2212_llll.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_700587.Sh_2212_lllljj.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_700591.Sh_2212_lllljj_Int.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_345060.PowhegPythia8EvtGen_NNLOPS_nnlo_30_ggH125_ZZ4l.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_346228.PowhegPy8EG_NNPDF30_AZNLOCTEQ6L1_VBFH125_ZZ4lep_notau.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_346646.PowhegPythia8EvtGen_NNPDF30_AZNLO_WpH125J_Wincl_MINLO_shw.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_346647.PowhegPythia8EvtGen_NNPDF30_AZNLO_WmH125J_Wincl_MINLO_shw.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_346645.PowhegPythia8EvtGen_NNPDF30_AZNLO_ZH125J_Zincl_MINLO_shw.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_345066.PowhegPythia8EvtGen_NNPDF3_AZNLO_ggZH125_ZZ4lepZinc.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_346340.PowhegPy8EG_A14NNPDF23_NNPDF30ME_ttH125_ZZ4l_allhad.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_346341.PowhegPy8EG_A14NNPDF23_NNPDF30ME_ttH125_ZZ4l_semilep.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
# File ODEO_FEB2025_v0_2to4lep_mc_346342.PowhegPy8EG_A14NNPDF23_NNPDF30ME_ttH125_ZZ4l_dilep.2to4lep.root already exists in backend/datasets/2to4lep/MC. Skipping download.
#
# Write data to output_directory: output/pt20_cut
#
# Processing "Data" samples
# 	backend/datasets/2to4lep/Data/ODEO_FEB2025_v0_2to4lep_data15_periodD.2to4lep.root :
# 		 nIn: 8802,	 nOut: 	1186	 in 0.1 s
# 	backend/datasets/2to4lep/Data/ODEO_FEB2025_v0_2to4lep_data15_periodE.2to4lep.root :
# 		 nIn: 65261,	 nOut: 	9687	 in 0.3 s
# 	backend/datasets/2to4lep/Data/ODEO_FEB2025_v0_2to4lep_data15_periodF.2to4lep.root :
# 		 nIn: 41832,	 nOut: 	5941	 in 0.2 s
# 	backend/datasets/2to4lep/Data/ODEO_FEB2025_v0_2to4lep_data15_periodG.2to4lep.root :
# 		 nIn: 93682,	 nOut: 	15017	 in 0.3 s
# 	backend/datasets/2to4lep/Data/ODEO_FEB2025_v0_2to4lep_data15_periodH.2to4lep.root :
# 		 nIn: 28656,	 nOut: 	5198	 in 0.1 s
# 	backend/datasets/2to4lep/Data/ODEO_FEB2025_v0_2to4lep_data15_periodJ.2to4lep.root :
# 		 nIn: 161720,	 nOut: 	29424	 in 0.5 s
# 	backend/datasets/2to4lep/Data/ODEO_FEB2025_v0_2to4lep_data16_periodA.2to4lep.root :
# 		 nIn: 73689,	 nOut: 	11628	 in 0.3 s
# 	backend/datasets/2to4lep/Data/ODEO_FEB2025_v0_2to4lep_data16_periodB.2to4lep.root :
# 		 nIn: 160015,	 nOut: 	33750	 in 0.5 s
# 	backend/datasets/2to4lep/Data/ODEO_FEB2025_v0_2to4lep_data16_periodC.2to4lep.root :
# 		 nIn: 207419,	 nOut: 	41107	 in 0.8 s
# 	backend/datasets/2to4lep/Data/ODEO_FEB2025_v0_2to4lep_data16_periodD.2to4lep.root :
# 		 nIn: 364708,	 nOut: 	90730	 in 0.8 s
# 	backend/datasets/2to4lep/Data/ODEO_FEB2025_v0_2to4lep_data16_periodE.2to4lep.root :
# 		 nIn: 113729,	 nOut: 	30224	 in 0.4 s
# 	backend/datasets/2to4lep/Data/ODEO_FEB2025_v0_2to4lep_data16_periodF.2to4lep.root :
# 		 nIn: 232306,	 nOut: 	63847	 in 0.7 s
# 	backend/datasets/2to4lep/Data/ODEO_FEB2025_v0_2to4lep_data16_periodG.2to4lep.root :
# 		 nIn: 263551,	 nOut: 	67852	 in 0.7 s
# 	backend/datasets/2to4lep/Data/ODEO_FEB2025_v0_2to4lep_data16_periodI.2to4lep.root :
# 		 nIn: 411269,	 nOut: 	107042	 in 0.9 s
# 	backend/datasets/2to4lep/Data/ODEO_FEB2025_v0_2to4lep_data16_periodK.2to4lep.root :
# 		 nIn: 164911,	 nOut: 	43972	 in 0.5 s
# 	backend/datasets/2to4lep/Data/ODEO_FEB2025_v0_2to4lep_data16_periodL.2to4lep.root :
# 		 nIn: 447961,	 nOut: 	116258	 in 1.0 s
# Processing "Signal Zee" samples
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_700320.Sh_2211_Zee_maxHTpTV2_BFilter.2to4lep.root :
# 		 nIn: 24697,	 nOut: 	13367.066	 in 0.2 s
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_700321.Sh_2211_Zee_maxHTpTV2_CFilterBVeto.2to4lep.root :
# 		 nIn: 109942,	 nOut: 	47845.973	 in 0.6 s
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_700322.Sh_2211_Zee_maxHTpTV2_CVetoBVeto.2to4lep.root :
# 		 nIn: 399444,	 nOut: 	245869.377	 in 1.4 s
# Processing "Signal Zmumu" samples
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_700323.Sh_2211_Zmumu_maxHTpTV2_BFilter.2to4lep.root :
# 		 nIn: 24378,	 nOut: 	13263.58	 in 0.3 s
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_700324.Sh_2211_Zmumu_maxHTpTV2_CFilterBVeto.2to4lep.root :
# 		 nIn: 115270,	 nOut: 	50477.065	 in 0.7 s
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_700325.Sh_2211_Zmumu_maxHTpTV2_CVetoBVeto.2to4lep.root :
# 		 nIn: 430696,	 nOut: 	271181.737	 in 1.8 s
# Processing "Background Wenu+Wmunu" samples
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_700338.Sh_2211_Wenu_maxHTpTV2_BFilter.2to4lep.root :
# 		 nIn: 6220,	 nOut: 	166.902	 in 0.1 s
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_700339.Sh_2211_Wenu_maxHTpTV2_CFilterBVeto.2to4lep.root :
# 		 nIn: 28590,	 nOut: 	692.487	 in 0.2 s
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_700340.Sh_2211_Wenu_maxHTpTV2_CVetoBVeto.2to4lep.root :
# 		 nIn: 19953,	 nOut: 	1207.192	 in 0.2 s
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_700341.Sh_2211_Wmunu_maxHTpTV2_BFilter.2to4lep.root :
# 		 nIn: 6602,	 nOut: 	203.533	 in 0.1 s
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_700342.Sh_2211_Wmunu_maxHTpTV2_CFilterBVeto.2to4lep.root :
# 		 nIn: 26473,	 nOut: 	692.388	 in 0.2 s
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_700343.Sh_2211_Wmunu_maxHTpTV2_CVetoBVeto.2to4lep.root :
# 		 nIn: 17640,	 nOut: 	1158.61	 in 0.2 s
# Processing "Background VV4l+H4l" samples
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_700600.Sh_2212_llll.2to4lep.root :
# 		 nIn: 1045,	 nOut: 	64.97	 in 0.1 s
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_700587.Sh_2212_lllljj.2to4lep.root :
# 		 nIn: 461,	 nOut: 	0.818	 in 0.1 s
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_700591.Sh_2212_lllljj_Int.2to4lep.root :
# 		 nIn: 59,	 nOut: 	1.915	 in 0.1 s
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_345060.PowhegPythia8EvtGen_NNLOPS_nnlo_30_ggH125_ZZ4l.2to4lep.root :
# 		 nIn: 13788,	 nOut: 	0.217	 in 0.3 s
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_346228.PowhegPy8EG_NNPDF30_AZNLOCTEQ6L1_VBFH125_ZZ4lep_notau.2to4lep.root :
# 		 nIn: 2604,	 nOut: 	0.018	 in 0.1 s
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_346646.PowhegPythia8EvtGen_NNPDF30_AZNLO_WpH125J_Wincl_MINLO_shw.2to4lep.root :
# 		 nIn: 490,	 nOut: 	0.013	 in 0.1 s
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_346647.PowhegPythia8EvtGen_NNPDF30_AZNLO_WmH125J_Wincl_MINLO_shw.2to4lep.root :
# 		 nIn: 259,	 nOut: 	0.007	 in 0.1 s
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_346645.PowhegPythia8EvtGen_NNPDF30_AZNLO_ZH125J_Zincl_MINLO_shw.2to4lep.root :
# 		 nIn: 867,	 nOut: 	0.01	 in 0.1 s
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_345066.PowhegPythia8EvtGen_NNPDF3_AZNLO_ggZH125_ZZ4lepZinc.2to4lep.root :
# 		 nIn: 278,	 nOut: 	0.002	 in 0.1 s
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_346340.PowhegPy8EG_A14NNPDF23_NNPDF30ME_ttH125_ZZ4l_allhad.2to4lep.root :
# 		 nIn: 262,	 nOut: 	0.002	 in 0.1 s
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_346341.PowhegPy8EG_A14NNPDF23_NNPDF30ME_ttH125_ZZ4l_semilep.2to4lep.root :
# 		 nIn: 231,	 nOut: 	0.001	 in 0.1 s
# 	backend/datasets/2to4lep/MC/ODEO_FEB2025_v0_2to4lep_mc_346342.PowhegPy8EG_A14NNPDF23_NNPDF30ME_ttH125_ZZ4l_dilep.2to4lep.root :
# 		 nIn: 174,	 nOut: 	0.0	 in 0.1 s
#
#
# Elapsed time: 26.4s

# %% [markdown]
# ## Reading Parquet Files
# You can read the files saved by `analysis_uproot` using the `analysis_read_parquet` function. Before reading large datesets, it is recommended to restart the kernel to clear memory.

# %%
read_directory = 'output/pt20_cut'
read_variables = ['lep_pt', 'mass']
pt20_data = analysis_read_parquet(read_variables, read_directory, 
                                  subdirectory_names=None,
                                  fraction=1, cut_function=None, 
                                  write_parquet=False,
                                  output_directory=None, return_output=True)
pt20_data
# Out:
# Elapsed time = 0.9s
# {'Signal Zmumu x1': <Array [{lep_pt: [...], mass: 91.7, ...}, ...] type='451974 * {lep_pt: var ...'>,
#  'Signal Zee x1': <Array [{lep_pt: [...], mass: 81.6, ...}, ...] type='425569 * {lep_pt: var ...'>,
#  'Data x1': <Array [{lep_pt: [...], mass: 96.5}, ...] type='672863 * {lep_pt: var * flo...'>,
#  'Background Wenu+Wmunu x1': <Array [{lep_pt: [...], mass: 32.4, ...}, ...] type='26068 * {lep_pt: var *...'>,
#  'Background VV4l+H4l x1': <Array [{lep_pt: [...], mass: 87.2, ...}, ...] type='3072 * {lep_pt: var * ...'>}

# %% [markdown]
# Similarly, you can also apply selection cuts and write filtered data to disk using `analysis_write_parquet`. Note that the function will create the dictionary keys by combining the subdirectory names with the `fraction`, separated by `' x'`.

# %% [markdown]
# ## Plotting Stacked Histograms
# The dictionary returned by `analysis_uproot` can be passed to `plot_stacked_hist` to plot stacked histograms.

# %%
# Variable to plot on the x-axis
plot_variable = 'mass'

# Define plot appearance
color_list = ['k', 'b', 'r', 'g', 'm']
xmin, xmax = 0, 120 # Define histogram bin range and x-axis limits 
num_bins = 500 # Number of histogram bins
x_label = 'mass [GeV]' # x-axis label 

# Plot the histogram
fig, hists = plot_stacked_hist(pt30_data, plot_variable, color_list,
                               num_bins, xmin, xmax, x_label,
                               show_text=False, save_fig=False)
# Out:
# Elapsed time = 1.9s

# %% [markdown]
# If you would like to plot many variables at once, you can use the `plot_histograms` function.

# %%
# Plot many variables at once 
plot_variables = ['lep_pt[0]', 'lep_pt[1]', 'mass']
xmin_xmax_list = (0, 120) # Bin range for all variables
# Define plot appearance
color_list = ['k', 'b', 'r', 'g', 'm']
num_bins_list = 300 
x_label_list = ['lep_pt[0] [GeV]', 'lep_pt[1] [GeV]', 'mass']

plot_histograms(
    pt30_data,
    plot_variables,
    color_list,
    xmin_xmax_list,
    num_bins_list,
    x_label_list)
# Out:
# Elapsed time = 1.2s
# Elapsed time = 3.5s
# Elapsed time = 5.9s
# ([<Figure size 1200x800 with 1 Axes>,
#   <Figure size 1200x800 with 1 Axes>,
#   <Figure size 1200x800 with 1 Axes>],
#  [[Hist(Regular(300, 0, 120, name='Data'), storage=Double()) # Sum: 427944.0 (434083.0 with flow),
#    Hist(Regular(300, 0, 120, name='Background Wenu+Wmunu'), storage=Weight()) # Sum: WeightedSum(value=1440.74, variance=2274.69) (WeightedSum(value=1719.47, variance=2359.07) with flow),
#    Hist(Regular(300, 0, 120, name='Background VV4l+H4l'), storage=Weight()) # Sum: WeightedSum(value=33.5041, variance=10.8603) (WeightedSum(value=34.4936, variance=11.0232) with flow),
#    Hist(Regular(300, 0, 120, name='Signal Zee'), storage=Weight()) # Sum: WeightedSum(value=217386, variance=855883) (WeightedSum(value=219588, variance=856922) with flow),
#    Hist(Regular(300, 0, 120, name='Signal Zmumu'), storage=Weight()) # Sum: WeightedSum(value=234224, variance=906390) (WeightedSum(value=235423, variance=907215) with flow)],
#   [Hist(Regular(300, 0, 120, name='Data'), storage=Double()) # Sum: 431398.0 (434083.0 with flow),
#    Hist(Regular(300, 0, 120, name='Background Wenu+Wmunu'), storage=Weight()) # Sum: WeightedSum(value=1567.17, variance=2330) (WeightedSum(value=1719.47, variance=2359.07) with flow),
#    Hist(Regular(300, 0, 120, name='Background VV4l+H4l'), storage=Weight()) # Sum: WeightedSum(value=33.8033, variance=10.8747) (WeightedSum(value=34.4936, variance=11.0232) with flow),
#    Hist(Regular(300, 0, 120, name='Signal Zee'), storage=Weight()) # Sum: WeightedSum(value=219231, variance=856294) (WeightedSum(value=219588, variance=856922) with flow),
#    Hist(Regular(300, 0, 120, name='Signal Zmumu'), storage=Weight()) # Sum: WeightedSum(value=234236, variance=906444) (WeightedSum(value=235423, variance=907215) with flow)],
#   [Hist(Regular(300, 0, 120, name='Data'), storage=Double()) # Sum: 422833.0 (434083.0 with flow),
#    Hist(Regular(300, 0, 120, name='Background Wenu+Wmunu'), storage=Weight()) # Sum: WeightedSum(value=769.639, variance=1887.35) (WeightedSum(value=1719.47, variance=2359.07) with flow),
#    Hist(Regular(300, 0, 120, name='Background VV4l+H4l'), storage=Weight()) # Sum: WeightedSum(value=31.3347, variance=9.98973) (WeightedSum(value=34.4936, variance=11.0232) with flow),
#    Hist(Regular(300, 0, 120, name='Signal Zee'), storage=Weight()) # Sum: WeightedSum(value=215369, variance=842989) (WeightedSum(value=219588, variance=856922) with flow),
#    Hist(Regular(300, 0, 120, name='Signal Zmumu'), storage=Weight()) # Sum: WeightedSum(value=231354, variance=894582) (WeightedSum(value=235423, variance=907215) with flow)]])

# %% [markdown]
# ## Plot Errorbars
# The `plot_errorbars` function is designed for cases where you want to:
# - Plot the same variable for different particles in the same event on the same figure, or
# - Compare the histogram under different selection cuts
#
# The first argument to this function must be a dictionary. Each value in this dictionary should also be a dictionary containing the keys `'color'`, `'array'`, and `'weight'`. The key of the outer dictionary will be used as the labels in the plot legend.
#
# This function returns a `Figure` object and a list of `Hist` objects.
#
# A few examples of using the function is shown in the code cells below.

# %%
data_dict = {
    'Data pt>20' : {'color' : 'r',
                    'array' : pt20_data['Data x1']['mass'],
                    'weight' : None},
    'Data pt>30' : {'color' : 'b',
                    'array' : pt30_data['Data']['mass'],
                    'weight' : None},
    'Zee pt>20' : {'color' : 'g',
                   'array' : pt20_data['Signal Zee x1']['mass'],
                   'weight' : pt20_data['Signal Zee x1']['totalWeight']},
    'Zee pt>30' : {'color' : 'm',
                   'array' : pt30_data['Signal Zee']['mass'],
                   'weight' : pt30_data['Signal Zee']['totalWeight']},
}

xmin, xmax = 60, 120
num_bins = 200
x_label = 'mass [GeV]'

plot_errorbars(data_dict,
               xmin,
               xmax,
               num_bins,
               x_label,
               # Optional arguments
               y_label='Events',
               logy=False,
               title='',
               marker='o',
               title_fontsize=17,
               label_fontsize=17,
               legend_fontsize=17,
               tick_labelsize=15,
               text_fontsize=14,
               show_text=False,
               fig_size=(12, 8))
# Out:
# Elapsed time = 0.1s
# (<Figure size 1200x800 with 1 Axes>,
#  [Hist(Regular(200, 60, 120, name='Data pt>20'), storage=Double()) # Sum: 522494.0 (672863.0 with flow),
#   Hist(Regular(200, 60, 120, name='Data pt>30'), storage=Double()) # Sum: 382103.0 (434083.0 with flow),
#   Hist(Regular(200, 60, 120, name='Zee pt>20'), storage=Weight()) # Sum: WeightedSum(value=295454, variance=1.11562e+06) (WeightedSum(value=307082, variance=1.15986e+06) with flow),
#   Hist(Regular(200, 60, 120, name='Zee pt>30'), storage=Weight()) # Sum: WeightedSum(value=214939, variance=842670) (WeightedSum(value=219588, variance=856922) with flow)])

# %%
data_dict = {
    'Data pt>20' : {'color' : 'r',
                    'array' : pt20_data['Data x1']['lep_pt'][:, 0],
                    'weight' : None},
    'Data pt>30' : {'color' : 'b',
                    'array' : pt30_data['Data']['lep_pt'][:, 0],
                    'weight' : None},
    'Zee pt>20' : {'color' : 'g',
                   'array' : pt20_data['Signal Zee x1']['lep_pt'][:, 0],
                   'weight' : pt20_data['Signal Zee x1']['totalWeight']},
    'Zee pt>30' : {'color' : 'm',
                   'array' : pt30_data['Signal Zee']['lep_pt'][:, 0],
                   'weight' : pt30_data['Signal Zee']['totalWeight']},
}

xmin, xmax = 60, 120
num_bins = 200
x_label = 'lep_pt[0] [GeV]'

plot_errorbars(data_dict,
               xmin,
               xmax,
               num_bins,
               x_label)
# Out:
# Elapsed time = 0.1s
# (<Figure size 1200x800 with 1 Axes>,
#  [Hist(Regular(200, 60, 120, name='Data pt>20'), storage=Double()) # Sum: 68816.0 (672863.0 with flow),
#   Hist(Regular(200, 60, 120, name='Data pt>30'), storage=Double()) # Sum: 43429.0 (434083.0 with flow),
#   Hist(Regular(200, 60, 120, name='Zee pt>20'), storage=Weight()) # Sum: WeightedSum(value=42815.4, variance=53404.4) (WeightedSum(value=307082, variance=1.15986e+06) with flow),
#   Hist(Regular(200, 60, 120, name='Zee pt>30'), storage=Weight()) # Sum: WeightedSum(value=26031.7, variance=36881.9) (WeightedSum(value=219588, variance=856922) with flow)])

# %%
data_dict = {
    'Data pt>20' : {'color' : 'r',
                    'array' : pt20_data['Data x1']['lep_pt'][:, 1], 
                    'weight' : None},
    'Data pt>30' : {'color' : 'b', 
                    'array' : pt30_data['Data']['lep_pt'][:, 1], 
                    'weight' : None},
    'Zee pt>20' : {'color' : 'g', 
                   'array' : pt20_data['Signal Zee x1']['lep_pt'][:, 1], 
                   'weight' : pt20_data['Signal Zee x1']['totalWeight']},
    'Zee pt>30' : {'color' : 'm', 
                   'array' : pt30_data['Signal Zee']['lep_pt'][:, 1], 
                   'weight' : pt30_data['Signal Zee']['totalWeight']},
}

xmin, xmax = 60, 120
num_bins = 200
x_label = 'lep_pt[1] [GeV]'

figure, hists = plot_errorbars(data_dict, xmin, xmax, num_bins, x_label)
# Out:
# Elapsed time = 0.1s

# %%
# You can use the Figure object returned by the function to save the figure as an image
figure.savefig('test.png', dpi=300)
